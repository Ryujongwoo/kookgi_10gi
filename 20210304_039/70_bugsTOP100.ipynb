# %%
import warnings
warnings.filterwarnings(action = 'ignore')
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
print(dt.now())
# Out:
# 2021-03-04 16:35:03.801243

# %%
targetSite = 'https://music.bugs.co.kr/chart'
request = requests.get(targetSite)
# print(request)
html = request.text
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# 노래 제목 크롤링
titles = soup.findAll('p', {'class': 'title'})
# print(titles)
# print(len(titles))
for title in titles:
    # print(title.text.strip())
    # print(title.text.split('\n')[1])
    print(title.text.strip().split('\n')[0])
# Out:
# 롤린 (Rollin')
# Celebrity
# 어떤 날은
# Don't Call Me
# 꼬리 (TAIL)
# 좋은 이별이 있을 리가 없잖아 (Feat. 조현아 Of 어반자카파)
# 사랑하는 당신께
# WHY DON'T WE (Feat. 청하)
# 멜로디
# 왜왜왜 (Why Why Why)
# 내 손을 잡아
# Dynamite
# 오늘도 난 봄을 기다려
# parachute
# I'm Not Cool
# 돌아갈 순 없을까 (Feat. 김세정)
# Lovesick Girls
# Bicycle
# HERO
# 밤하늘의 별을(2020)
# 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)
# 잘 가
# 함께 했는데 이별은 나 혼자인 거야
# 그 강을 건너지마오
# 아로하
# Bang!
# VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
# 서른 밤째 (바른연애 길잡이 X 윤하 (YOUNHA))
# 물망초 (Feat. 신용재)
# 사랑, 이게 맞나 봐
# CREDIT (Feat. 염따, 기리보이, Zion.T)
# 에잇(Prod.&Feat. SUGA of BTS)
# Blueming
# FRIENDS (Prod. Slom)
# 마음이 그래
# Dolphin
# When We Disco (Duet with 선미)
# Panorama
# 이제 나만 믿어요
# STAR (Feat. 챈슬러, D.Ark)
# 쉴 곳 (Feat. 김영흠)
# Love poem
# 잠이 오질 않네요
# 고백 (바른연애 길잡이 X 허각)
# At My Worst
# What Do I Call You
# 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
# 거북이 (Feat. 효린) (Remix Ver.)
# 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
# Life Goes On
# 밝게 빛나는 별이 되어 비춰줄게
# 사랑한단 거짓말은 안 할래
# 취기를 빌려 (취향저격 그녀 X 산들)
# 우린 어쩌다 헤어진 걸까
# 모든 날, 모든 순간 (Every day, Every Moment)
# For You (Feat. Crush)
# 그댈 새겨두어요 (바른연애 길잡이 X 린)
# 밤편지
# I CAN’T STOP ME
# Your Lights
# How You Like That
# 화(火花)
# Savage Love (Laxed - Siren Beat) (BTS Remix)
# Black Mamba
# 내 얘기 같아 (Feat. 헤이즈)
# 가을밤에 든 생각
# 눈이 멀었다
# 술 한잔 해요
# 나로 바꾸자 (duet with JYP)
# 시작
# 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 오래된 노래
# 2002
# 34+35
# 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
# Memories
# 좋아해.. (바른연애 길잡이 X 죠지)
# 주저하는 연인들을 위해
# 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# Beautiful Mistakes
# 마음을 드려요
# Ashes
# 화병
# 입김
# Square (2017)
# 살짝 설렜어 (Nonstop)
# METEOR
# Heart Attack
# 휘파람
# Bad Boy
# Beautiful Beautiful
# Rosario (Feat. CL, ZICO)
# DNA
# 바램
# 어느 60대 노부부이야기
# Marry You
# 사라진 모든 것들에게(with ELLE KOREA)
# 아무렇지 않은 사람
# CØDE
# 어른처럼 (With. 죠지)

# %%
# 아티스트 크롤링
artists = soup.findAll('p', {'class': 'artist'})
# print(artists)
# print(len(artists))
i = 0
for artist in artists:
    i += 1
    print(i, artist.text.strip().split('\n')[0])
# Out:
# 1 브레이브걸스(Brave Girls)
# 2 아이유(IU)
# 3 김필(Kim Feel)
# 4 SHINee (샤이니)
# 5 선미
# 6 MC몽
# 7 폴킴(Paul Kim)
# 8 비
# 9 ASH ISLAND
# 10 iKON
# 11 아이유(IU)
# 12 방탄소년단
# 13 케이시
# 14 John K
# 15 현아
# 16 MC몽
# 17 BLACKPINK
# 18 청하
# 19 임영웅
# 20 경서
# 21 10CM
# 22 권진아
# 23 소정(레이디스 코드)
# 24 양지은
# 25 조정석
# 26 AJR
# 27 미란이
# 28 윤하(Younha/ユンナ)
# 29 MC몽
# 30 DAY6 (Even of Day)
# 31 릴보이(lIlBOI)
# 32 아이유(IU)
# 33 아이유(IU)
# 34 릴보이(lIlBOI)
# 35 개코
# 36 오마이걸(OH MY GIRL)
# 37 박진영
# 38 IZ*ONE(아이즈원)
# 39 임영웅
# 40 MC몽
# 41 MC몽
# 42 아이유(IU)
# 43 장범준
# 44 허각
# 45 Pink Sweat$
# 46 태연 (TAEYEON)
# 47 적재
# 48 MC몽
# 49 장범준
# 50 방탄소년단
# 51 송이한
# 52 먼데이 키즈(Monday Kiz)
# 53 산들
# 54 허각
# 55 폴킴(Paul Kim)
# 56 이하이
# 57 린(LYn)
# 58 아이유(IU)
# 59 TWICE (트와이스)
# 60 이수 (엠씨더맥스)
# 61 BLACKPINK
# 62 (여자)아이들
# 63 Jawsh 685
# 64 aespa
# 65 에픽하이 (EPIK HIGH)
# 66 잔나비
# 67 MC몽
# 68 경서 (경서예지)
# 69 비
# 70 가호(Gaho)
# 71 AKMU (악동뮤지션)
# 72 스탠딩 에그(Standing Egg)
# 73 Anne-Marie(앤 마리)
# 74 Ariana Grande(아리아나 그란데)
# 75 규현 (KYUHYUN)
# 76 Maroon 5(마룬 파이브)
# 77 죠지
# 78 잔나비
# 79 방탄소년단
# 80 Maroon 5(마룬 파이브)
# 81 아이유(IU)
# 82 Stellar
# 83 MC몽
# 84 10CM
# 85 백예린 (Yerin Baek)
# 86 오마이걸(OH MY GIRL)
# 87 창모(CHANGMO)
# 88 SHINee (샤이니)
# 89 이무진
# 90 청하
# 91 온앤오프(ONF)
# 92 에픽하이 (EPIK HIGH)
# 93 방탄소년단
# 94 임영웅
# 95 임영웅
# 96 SHINee (샤이니)
# 97 코드 쿤스트
# 98 카더가든
# 99 SHINee (샤이니)
# 100 권진아

# %%
print(dt.now())
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print('{0:3d}위 {1} - {2}'.format(i + 1, artist, title))
# Out:
# 2021-03-04 17:20:07.817966
#   1위 브레이브걸스(Brave Girls) - 롤린 (Rollin')
#   2위 아이유(IU) - Celebrity
#   3위 김필(Kim Feel) - 어떤 날은
#   4위 SHINee (샤이니) - Don't Call Me
#   5위 선미 - 꼬리 (TAIL)
#   6위 MC몽 - 좋은 이별이 있을 리가 없잖아 (Feat. 조현아 Of 어반자카파)
#   7위 폴킴(Paul Kim) - 사랑하는 당신께
#   8위 비 - WHY DON'T WE (Feat. 청하)
#   9위 ASH ISLAND - 멜로디
#  10위 iKON - 왜왜왜 (Why Why Why)
#  11위 아이유(IU) - 내 손을 잡아
#  12위 방탄소년단 - Dynamite
#  13위 케이시 - 오늘도 난 봄을 기다려
#  14위 John K - parachute
#  15위 현아 - I'm Not Cool
#  16위 MC몽 - 돌아갈 순 없을까 (Feat. 김세정)
#  17위 BLACKPINK - Lovesick Girls
#  18위 청하 - Bicycle
#  19위 임영웅 - HERO
#  20위 경서 - 밤하늘의 별을(2020)
#  21위 10CM - 이 밤을 빌려 말해요 (바른연애 길잡이 X 10CM)
#  22위 권진아 - 잘 가
#  23위 소정(레이디스 코드) - 함께 했는데 이별은 나 혼자인 거야
#  24위 양지은 - 그 강을 건너지마오
#  25위 조정석 - 아로하
#  26위 AJR - Bang!
#  27위 미란이 - VVS (Feat. JUSTHIS) (Prod. GroovyRoom)
#  28위 윤하(Younha/ユンナ) - 서른 밤째 (바른연애 길잡이 X 윤하 (YOUNHA))
#  29위 MC몽 - 물망초 (Feat. 신용재)
#  30위 DAY6 (Even of Day) - 사랑, 이게 맞나 봐
#  31위 릴보이(lIlBOI) - CREDIT (Feat. 염따, 기리보이, Zion.T)
#  32위 아이유(IU) - 에잇(Prod.&Feat. SUGA of BTS)
#  33위 아이유(IU) - Blueming
#  34위 릴보이(lIlBOI) - FRIENDS (Prod. Slom)
#  35위 개코 - 마음이 그래
#  36위 오마이걸(OH MY GIRL) - Dolphin
#  37위 박진영 - When We Disco (Duet with 선미)
#  38위 IZ*ONE(아이즈원) - Panorama
#  39위 임영웅 - 이제 나만 믿어요
#  40위 MC몽 - STAR (Feat. 챈슬러, D.Ark)
#  41위 MC몽 - 쉴 곳 (Feat. 김영흠)
#  42위 아이유(IU) - Love poem
#  43위 장범준 - 잠이 오질 않네요
#  44위 허각 - 고백 (바른연애 길잡이 X 허각)
#  45위 Pink Sweat$ - At My Worst
#  46위 태연 (TAEYEON) - What Do I Call You
#  47위 적재 - 나랑 같이 걸을래 (바른연애 길잡이 X 적재)
#  48위 MC몽 - 거북이 (Feat. 효린) (Remix Ver.)
#  49위 장범준 - 흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야
#  50위 방탄소년단 - Life Goes On
#  51위 송이한 - 밝게 빛나는 별이 되어 비춰줄게
#  52위 먼데이 키즈(Monday Kiz) - 사랑한단 거짓말은 안 할래
#  53위 산들 - 취기를 빌려 (취향저격 그녀 X 산들)
#  54위 허각 - 우린 어쩌다 헤어진 걸까
#  55위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
#  56위 이하이 - For You (Feat. Crush)
#  57위 린(LYn) - 그댈 새겨두어요 (바른연애 길잡이 X 린)
#  58위 아이유(IU) - 밤편지
#  59위 TWICE (트와이스) - I CAN’T STOP ME
#  60위 이수 (엠씨더맥스) - Your Lights
#  61위 BLACKPINK - How You Like That
#  62위 (여자)아이들 - 화(火花)
#  63위 Jawsh 685 - Savage Love (Laxed - Siren Beat) (BTS Remix)
#  64위 aespa - Black Mamba
#  65위 에픽하이 (EPIK HIGH) - 내 얘기 같아 (Feat. 헤이즈)
#  66위 잔나비 - 가을밤에 든 생각
#  67위 MC몽 - 눈이 멀었다
#  68위 경서 (경서예지) - 술 한잔 해요
#  69위 비 - 나로 바꾸자 (duet with JYP)
#  70위 가호(Gaho) - 시작
#  71위 AKMU (악동뮤지션) - 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
#  72위 스탠딩 에그(Standing Egg) - 오래된 노래
#  73위 Anne-Marie(앤 마리) - 2002
#  74위 Ariana Grande(아리아나 그란데) - 34+35
#  75위 규현 (KYUHYUN) - 내 마음이 움찔했던 순간 (취향저격 그녀 X 규현)
#  76위 Maroon 5(마룬 파이브) - Memories
#  77위 죠지 - 좋아해.. (바른연애 길잡이 X 죠지)
#  78위 잔나비 - 주저하는 연인들을 위해
#  79위 방탄소년단 - 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
#  80위 Maroon 5(마룬 파이브) - Beautiful Mistakes
#  81위 아이유(IU) - 마음을 드려요
#  82위 Stellar - Ashes
#  83위 MC몽 - 화병
#  84위 10CM - 입김
#  85위 백예린 (Yerin Baek) - Square (2017)
#  86위 오마이걸(OH MY GIRL) - 살짝 설렜어 (Nonstop)
#  87위 창모(CHANGMO) - METEOR
#  88위 SHINee (샤이니) - Heart Attack
#  89위 이무진 - 휘파람
#  90위 청하 - Bad Boy
#  91위 온앤오프(ONF) - Beautiful Beautiful
#  92위 에픽하이 (EPIK HIGH) - Rosario (Feat. CL, ZICO)
#  93위 방탄소년단 - DNA
#  94위 임영웅 - 바램
#  95위 임영웅 - 어느 60대 노부부이야기
#  96위 SHINee (샤이니) - Marry You
#  97위 코드 쿤스트 - 사라진 모든 것들에게(with ELLE KOREA)
#  98위 카더가든 - 아무렇지 않은 사람
#  99위 SHINee (샤이니) - CØDE
# 100위 권진아 - 어른처럼 (With. 죠지)
