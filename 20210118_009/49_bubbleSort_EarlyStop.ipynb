# %% [markdown]
# 버블 정렬은 데이터가 어느정도 정렬이 되어있는 상태라면 회전수를 다 채우지 않아도 정렬이 완료되었나 판단해서 조기에 종료할 수 있다.

# %%
from IPython.display import Image
Image('./bubbleSort_2.png', width = '600')

# %%
data = [9, 1, 3, 4, 8]

for i in range(len(data) - 1):
    
    # ⓐ => 회전(정렬) 작업이 시작되기 전에 flag 변수를 선언하고 False로 초기화시킨다.
    flag = False
    
    for j in range(len(data) - 1 - i):
        if data[j] > data[j + 1]:
            data[j], data[j + 1] = data[j + 1], data[j]
            # ⓑ => 값 교환 작업이 실행되면 flag 변수의 값을 True로 수정한다.
            flag = True
    # ===== for j 끝 => 회전 종료
    
    # ⓒ => 한 회전이 종료되었을 때 값 교환 작업이 한 번도 실행되지 않았다면 현재 데이터는 모두 정렬이 되어있는 상태를 의미하므로
    # 정렬을 중지시킨다.
    # if flag == False:
    if not flag:
        print('{} 회전을 해야하지만 {} 회전 후 중간 종료됨'.format(len(data) - 1, i + 1))
        break
    
    print('{} 회전 결과 : {}'.format(i + 1, data))
# ===== for i 끝 => 정렬 종료
# print('정렬 결과 : {}'.format(data))
# Out:
# 1 회전 결과 : [1, 3, 4, 8, 9]
# 4 회전을 해야하지만 2 회전 후 중간 종료됨
